# %%
import re


def process_line(line):
	# Replace sentence-ending punctuation with <eos>
	line = re.sub(r'([.!?])', ' <eos> ', line)
	# Insert spaces around specific punctuation to ensure they are treated as separate tokens
	line = re.sub(r'([{[\]()},$])', r' \1 ', line)
	# Collapse multiple spaces into a single space
	line = re.sub(r'\s{2,}', ' ', line)
	line = line.lower().strip()

	# Split the line into tokens
	tokens = line.split()

	# Handle special case where <eos> is followed by }
	if len(tokens) >= 2 and tokens[-2] == "<eos>":
		tokens[-2], tokens[-1] = tokens[-1], tokens[-2]

	latex_mode = False
	latex_stack = ""
	tokenized_line = ['<sos>']

	for token in tokens:
		if latex_mode:
			latex_stack += token
			if token == "$":
				latex_mode = False
				# latex_stack = latex_stack.replace(" ", "")
				latex_stack = '<ltx>'
				tokenized_line.append(latex_stack)
				latex_stack = ""
		elif token == "$":
			latex_mode = True
			latex_stack += token
		else:
			if latex_stack:
				# latex_stack = latex_stack.replace(" ", "")
				latex_stack = '<ltx>'
				tokenized_line.append(latex_stack)
				latex_stack = ""
			tokenized_line.append(token)

	# Append any remaining LaTeX stack
	if latex_stack:
		# latex_stack = latex_stack.replace(" ", "")
		latex_stack = '<ltx>'
		tokenized_line.append(latex_stack)
	text = " ".join(tokenized_line)
	text = re.sub(r"\\", "  ", text)
	text = re.sub(r"(<eos>)(\w)+", "\1", text)
	text = re.sub(r"(\d)+", " <num> ", text)
	text = re.sub(r"[\(\[\{]", " <opn> ", text)
	text = re.sub(r"[\)\]\}]", " <cld> ", text)
	text = re.sub(r"\\\w+\b", " <ltx> ", text)
	text = re.sub(r"(\\%|%)", "<prc>", text)
	text = re.sub(r",", "<com>", text)
	text = re.sub(r"/", " ", text)
	text = re.sub(r"-", " ", text)
	text = re.sub(r"[^\w<>]", " ", text)
	return text.split()


def normalize_data(data, dest):
	tokenized_data = []
	vocab = set()
	with open(dest, 'w+') as dest_file:
		for line in data:
			if len(line) > 0 and line[0] != "%":
				line = process_line(line)
				vocab = vocab.union(set(line))
				line = " ".join(line)
				dest_file.write(line + "\n")
	print(f">>> {source}, {target} Done!")
	return vocab

# %%
DATA = (("data414_2020_a1.af.txt", "data414_2020_a1.en.txt"),
	("data414_2021_a1.af.txt", "data414_2021_a1.en.txt"),
	("data414_2021_a2.af.txt", "data414_2021_a2.en.txt"),
	("ss414_2018_a1.af.txt", "ss414_2018_a1.en.txt"),
	("ss414_2018_a2.af.txt", "ss414_2018_a2.en.txt"),
	("ss414_2018_a3.af.txt", "ss414_2018_a3.en.txt"),
	("ss414_2019_a1.af.txt", "ss414_2019_a1.en.txt"),
	("ss414_2019_a2.af.txt", "ss414_2019_a2.en.txt"),
	("ss414_2019_a3.af.txt", "ss414_2019_a3.en.txt"))

# %%
English = set()
Afrikans = set()
for source, target in DATA:
    with open(source) as file:
	    data = file.read()
    data = data.strip().split("\n")
    vocab = normalize_data(data, f"norm/{source}")
    Afrikans = Afrikans.union(vocab)
    
    with open(target) as file:
	    data = file.read()
    data = data.strip().split("\n")
    vocab = normalize_data(data, f"norm/{target}")
    English = English.union(vocab)
# Out:
# >>> data414_2020_a1.af.txt, data414_2020_a1.en.txt Done!
# >>> data414_2020_a1.af.txt, data414_2020_a1.en.txt Done!
# >>> data414_2021_a1.af.txt, data414_2021_a1.en.txt Done!
# >>> data414_2021_a1.af.txt, data414_2021_a1.en.txt Done!
# >>> data414_2021_a2.af.txt, data414_2021_a2.en.txt Done!
# >>> data414_2021_a2.af.txt, data414_2021_a2.en.txt Done!
# >>> ss414_2018_a1.af.txt, ss414_2018_a1.en.txt Done!
# >>> ss414_2018_a1.af.txt, ss414_2018_a1.en.txt Done!
# >>> ss414_2018_a2.af.txt, ss414_2018_a2.en.txt Done!
# >>> ss414_2018_a2.af.txt, ss414_2018_a2.en.txt Done!
# >>> ss414_2018_a3.af.txt, ss414_2018_a3.en.txt Done!
# >>> ss414_2018_a3.af.txt, ss414_2018_a3.en.txt Done!
# >>> ss414_2019_a1.af.txt, ss414_2019_a1.en.txt Done!
# >>> ss414_2019_a1.af.txt, ss414_2019_a1.en.txt Done!
# >>> ss414_2019_a2.af.txt, ss414_2019_a2.en.txt Done!
# >>> ss414_2019_a2.af.txt, ss414_2019_a2.en.txt Done!
# >>> ss414_2019_a3.af.txt, ss414_2019_a3.en.txt Done!
# >>> ss414_2019_a3.af.txt, ss414_2019_a3.en.txt Done!

# %%
def build_vocab(files)
V = {
	"<pad>": 0,
	"<sos>": 1,
	"<eos>": 2,
	"<unk>": 3,
	"<num>": 4,
	"<com>": 5,
	"<prc>": 6,
	"<opn>": 7,
	"<cld>": 8,
	"<ltx>": 9,
}

# %%
# sorted(list(English), key=lambda x: len(x))
English
# Out:
# {'<cld>',
#  '<com>',
#  '<eos>',
#  '<ltx>',
#  '<num>',
#  '<opn>',
#  '<prc>',
#  '<sos>',
#  'a',
#  'about',
#  'above',
#  'accidentally',
#  'accomplish',
#  'according',
#  'accuracies',
#  'accuracy',
#  'actually',
#  'adc',
#  'add',
#  'adding',
#  'additional',
#  'additive',
#  'advisable',
#  'affect',
#  'affected',
#  'after',
#  'again',
#  'aim',
#  'algebraically',
#  'algorithm',
#  'aliasing',
#  'all',
#  'also',
#  'alternative',
#  'amplitude',
#  'amplitudes',
#  'an',
#  'analog',
#  'analogue',
#  'analysed',
#  'analysis',
#  'analytics',
#  'and',
#  'annotate',
#  'another',
#  'answer',
#  'answering',
#  'answers',
#  'anti',
#  'any',
#  'anything',
#  'aperiodic',
#  'applied',
#  'apply',
#  'approach',
#  'approaches',
#  'appropriate',
#  'are',
#  'around',
#  'array',
#  'artist',
#  'as',
#  'assigned',
#  'assignment',
#  'assignments',
#  'associative',
#  'assume',
#  'assumed',
#  'assuming',
#  'assumption',
#  'assumptions',
#  'assuring',
#  'at',
#  'audio',
#  'autocorrelation',
#  'automatically',
#  'average',
#  'avoid',
#  'away',
#  'axes',
#  'axis',
#  'b',
#  'back',
#  'band',
#  'bandwidth',
#  'base',
#  'based',
#  'basis',
#  'bass',
#  'bayes',
#  'be',
#  'beats',
#  'been',
#  'before',
#  'behaviour',
#  'below',
#  'between',
#  'bias',
#  'bilinear',
#  'binary',
#  'bits',
#  'block',
#  'boosting',
#  'both',
#  'boundaries',
#  'bpf',
#  'branch',
#  'british',
#  'budget',
#  'build',
#  'but',
#  'butterfly',
#  'butterworth',
#  'by',
#  'c',
#  'calculate',
#  'calculates',
#  'calculating',
#  'calculation',
#  'calculations',
#  'can',
#  'case',
#  'cases',
#  'categorical',
#  'causal',
#  'cause',
#  'centered',
#  'centred',
#  'centroid',
#  'centroids',
#  'ceo',
#  'change',
#  'changes',
#  'characterised',
#  'charged',
#  'choose',
#  'chosen',
#  'circle',
#  'circular',
#  'class',
#  'classes',
#  'classification',
#  'classifier',
#  'classifiers',
#  'classifies',
#  'classifying',
#  'clearly',
#  'close',
#  'closed',
#  'cluster',
#  'clustering',
#  'clusters',
#  'code',
#  'coefficient',
#  'coefficients',
#  'collect',
#  'colour',
#  'comes',
#  'compare',
#  'compared',
#  'competition',
#  'complete',
#  'components',
#  'compression',
#  'computations',
#  'compute',
#  'computed',
#  'concept',
#  'conditional',
#  'configuration',
#  'consider',
#  'considered',
#  'considering',
#  'consists',
#  'constant',
#  'containing',
#  'contains',
#  'continuous',
#  'converge',
#  'convergence',
#  'converter',
#  'converters',
#  'convolution',
#  'correct',
#  'correlation',
#  'correspond',
#  'corrupted',
#  'coughing',
#  'could',
#  'covariance',
#  'covid',
#  'cross',
#  'crosses',
#  'currently',
#  'curve',
#  'cutoff',
#  'cycles',
#  'd',
#  'dac',
#  'data',
#  'dataset',
#  'db',
#  'decide',
#  'decided',
#  'decimation',
#  'decision',
#  'decreasing',
#  'defined',
#  'definition',
#  'definitions',
#  'denote',
#  'denotes',
#  'density',
#  'depth',
#  'derivation',
#  'describe',
#  'described',
#  'describes',
#  'design',
#  'desirable',
#  'desired',
#  'determine',
#  'determining',
#  'develops',
#  'dft',
#  'diagonal',
#  'diagram',
#  'die',
#  'difference',
#  'different',
#  'differently',
#  'digital',
#  'dimension',
#  'dimensional',
#  'dimensions',
#  'direct',
#  'directly',
#  'discrete',
#  'discretised',
#  'distance',
#  'distribution',
#  'do',
#  'doctor',
#  'does',
#  'dollars',
#  'domain',
#  'don',
#  'down',
#  'downsampled',
#  'downsampling',
#  'draw',
#  'drum',
#  'drums',
#  'dsp',
#  'dtft',
#  'dtmf',
#  'dual',
#  'duration',
#  'e',
#  'each',
#  'earlier',
#  'earn',
#  'effect',
#  'effects',
#  'efficient',
#  'efficiently',
#  'employees',
#  'en',
#  'encode',
#  'end',
#  'energy',
#  'engineer',
#  'enough',
#  'ensuring',
#  'equation',
#  'equations',
#  'equivalent',
#  'error',
#  'estimate',
#  'estimates',
#  'estimation',
#  'euclidean',
#  'euro',
#  'evaluate',
#  'evaluation',
#  'even',
#  'every',
#  'exactly',
#  'example',
#  'except',
#  'exchange',
#  'executed',
#  'execution',
#  'existing',
#  'expect',
#  'explain',
#  'expression',
#  'extensive',
#  'factor',
#  'factors',
#  'fail',
#  'failure',
#  'false',
#  'fast',
#  'feature',
#  'features',
#  'feeds',
#  'female',
#  'females',
#  'fewer',
#  'fft',
#  'ffts',
#  'figure',
#  'filter',
#  'filters',
#  'final',
#  'finally',
#  'finite',
#  'fir',
#  'firm',
#  'firms',
#  'first',
#  'fit',
#  'fits',
#  'five',
#  'fixed',
#  'floating',
#  'flowers',
#  'followed',
#  'following',
#  'follows',
#  'for',
#  'form',
#  'formula',
#  'formulas',
#  'fourier',
#  'frame',
#  'frequencies',
#  'frequency',
#  'freqz',
#  'friend',
#  'from',
#  'full',
#  'function',
#  'functions',
#  'fundamental',
#  'furthest',
#  'future',
#  'gaussian',
#  'gaussians',
#  'gender',
#  'general',
#  'generates',
#  'generating',
#  'generator',
#  'german',
#  'get',
#  'give',
#  'given',
#  'giving',
#  'goal',
#  'good',
#  'gradients',
#  'graduation',
#  'graph',
#  'greatly',
#  'greedy',
#  'ground',
#  'group',
#  'growing',
#  'grown',
#  'had',
#  'hamming',
#  'hand',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'high',
#  'higher',
#  'hint',
#  'hot',
#  'how',
#  'however',
#  'hz',
#  'i',
#  'ideal',
#  'identities',
#  'idft',
#  'if',
#  'ii',
#  'image',
#  'imaginary',
#  'implement',
#  'implemented',
#  'improve',
#  'improved',
#  'improves',
#  'impulse',
#  'in',
#  'include',
#  'incorrectly',
#  'increased',
#  'increasing',
#  'independent',
#  'index',
#  'indicate',
#  'indicated',
#  'indicating',
#  'indices',
#  'individual',
#  'industry',
#  'inference',
#  'infinite',
#  'initial',
#  'initialisation',
#  'input',
#  'inputs',
#  'instance',
#  'instantaneous',
#  'instead',
#  'integer',
#  'intend',
#  'interested',
#  'interpret',
#  'interval',
#  'into',
#  'invariant',
#  'inverse',
#  'iq',
#  'iris',
#  'is',
#  'isolate',
#  'it',
#  'item',
#  'items',
#  'iteration',
#  'its',
#  'just',
#  'khz',
#  'kit',
#  'know',
#  'knowing',
#  'knows',
#  'label',
#  'labelled',
#  'labelling',
#  'labels',
#  'launched',
#  'launching',
#  'lead',
#  'leaf',
#  'learned',
#  'learning',
#  'least',
#  'lecturer',
#  'length',
#  'let',
#  'level',
#  'levels',
#  'library',
#  'like',
#  'likelihood',
#  'limited',
#  'line',
#  'linear',
#  'linearly',
#  'lines',
#  'list',
#  'lobe',
#  'log',
#  'logistic',
#  'look',
#  'looking',
#  'loss',
#  'low',
#  'lower',
#  'lpf',
#  'lti',
#  'lying',
#  'machine',
#  'made',
#  'magnitude',
#  'main',
#  'make',
#  'makes',
#  'making',
#  'male',
#  'males',
#  'mapping',
#  'mark',
#  'market',
#  'marketing',
#  'markets',
#  'mathematical',
#  'matric',
#  'matrix',
#  'maximum',
#  'may',
#  'mbox',
#  'mean',
#  'means',
#  'measure',
#  'meeting',
#  'method',
#  'methods',
#  'minimal',
#  'minimise',
#  'minimising',
#  'minimum',
#  'model',
#  'modelled',
#  'models',
#  'more',
#  'most',
#  'motivate',
#  'ms',
#  'multi',
#  'multidimensional',
#  'multiple',
#  'multiplication',
#  'multiplications',
#  'multivariate',
#  'music',
#  'must',
#  'n',
#  'naive',
#  'nearest',
#  'necessary',
#  'needs',
#  'neelsie',
#  'negative',
#  'neigbour',
#  'neigbours',
#  'neighbours',
#  'new',
#  'next',
#  'nll',
#  'nodes',
#  'noise',
#  'non',
#  'normalisation',
#  'normally',
#  'not',
#  'notch',
#  'notches',
#  'note',
#  'now',
#  'number',
#  'numeric',
#  'nyquist',
#  'observation',
#  'observations',
#  'observe',
#  'obtain',
#  'obtained',
#  'obtains',
#  'occupation',
#  'occurred',
#  'occurs',
#  'odd',
#  'of',
#  'ola',
#  'on',
#  'one',
#  'only',
#  'optimal',
#  'optimise',
#  'or',
#  'order',
#  'origin',
#  'original',
#  'other',
#  'others',
#  'our',
#  'out',
#  'output',
#  'outputs',
#  'over',
#  'overlap',
#  'own',
#  'padding',
#  'page',
#  'pairs',
#  'parameter',
#  'parameters',
#  'parametrised',
#  'part',
#  'particular',
#  'pass',
#  'passed',
#  'pca',
#  'per',
#  'perform',
#  'performance',
#  'period',
#  'periodic',
#  'periods',
#  'person',
#  'phase',
#  'pixels',
#  'placing',
#  'play',
#  'plot',
#  'plots',
#  'point',
#  'points',
#  'poles',
#  'polynomials',
#  'poorly',
#  'portion',
#  'positive',
#  'possible',
#  'power',
#  'precision',
#  'predicted',
#  'predicting',
#  'prediction',
#  'predictions',
#  'predicts',
#  'preprocess',
#  'preprocessing',
#  'previously',
#  'price',
#  'principal',
#  'problem',
#  'problematic',
#  'problems',
#  'proceed',
#  'process',
#  'processing',
#  'processor',
#  'produces',
#  'producing',
#  'product',
#  'products',
#  'profit',
#  'projecting',
#  'projection',
#  'property',
#  'prototype',
#  'prove',
#  'provided',
#  'provides',
#  'purely',
#  'purpose',
#  'python',
#  'quantisation',
#  'question',
#  'questions',
#  'rad',
#  'radial',
#  'radians',
#  'radix',
#  'random',
#  'range',
#  'rate',
#  'rather',
#  'ratio',
#  'raw',
#  'rbf',
#  'rbfs',
#  'real',
#  'really',
#  'recall',
#  'recommend',
#  'reconstructed',
#  'record',
#  'recorded',
#  'recording',
#  'recordings',
#  'redundant',
#  'refer',
#  'referring',
#  'region',
#  'regions',
#  'regression',
#  'regularisation',
#  'relation',
#  'relationship',
#  'repeat',
#  'repeated',
#  'represent',
#  'representation',
#  'represents',
#  'require',
#  'required',
#  'requirements',
#  'research',
#  'resolution',
#  'respectively',
#  'response',
#  'result',
#  'resulting',
#  'results',
#  'revisit',
#  'roc',
#  'rough',
#  'run',
#  'running',
#  's',
#  'salary',
#  'sales',
#  'same',
#  'sample',
#  'sampled',
#  'samples',
#  'sampling',
#  'saving',
#  'say',
#  'scalar',
#  'scenario',
#  'scenarios',
#  'scipy',
#  'score',
#  'second',
#  'seconds',
#  'see',
#  'seen',
#  'selected',
#  'sensible',
#  'separately',
#  'separation',
#  'set',
#  'settings',
#  'several',
#  'she',
#  'sheet',
#  'short',
#  'shortly',
#  'should',
#  'show',
#  'shown',
#  'shows',
#  'signal',
#  'signals',
#  'similar',
#  'simple',
#  'single',
#  'sinusoid',
#  'sinusoidal',
#  'six',
#  'sketch',
#  'skip',
#  'slightly',
#  'smallest',
#  'sne',
#  'snippet',
#  'so',
#  'softmax',
#  'some',
#  'someone',
#  'sometimes',
#  'song',
#  'space',
#  'spaced',
#  'spar',
#  'specific',
#  'specifically',
#  'spectra',
#  'spectral',
#  'spectrogram',
#  'spectrum',
#  'spectum',
#  'speed',
#  'squared',
#  'squares',
#  'stable',
#  'standardize',
#  'starting',
#  'state',
#  'stated',
#  'stationary',
#  'statistical',
#  'stays',
#  'step',
#  'steps',
#  'stft',
#  'still',
#  'stock',
#  'store',
#  'stored',
#  'strategy',
#  'student',
#  'stumps',
#  'subsequences',
#  'subtract',
#  'success',
#  'such',
#  'sum',
#  'suppose',
#  'sure',
#  'system',
#  'systems',
#  't',
#  'table',
#  'take',
#  'takes',
#  'taking',
#  'target',
#  'technique',
#  'tells',
#  'ten',
#  'term',
#  'terms',
#  'test',
#  'testing',
#  'textbf',
#  'textit',
#  'texttt',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'then',
#  'there',
#  'thereafter',
#  'therefore',
#  'these',
#  'they',
#  'think',
#  'third',
#  'this',
#  'thoroughly',
#  'thousands',
#  'three',
#  'through',
#  'time',
#  'times',
#  'to',
#  'tone',
#  'too',
#  'top',
#  'train',
#  'trained',
#  'training',
#  'transfer',
#  'transform',
#  'transformation',
#  'transformations',
#  'treat',
#  'tree',
#  'trees',
#  'true',
#  'truth',
#  'turn',
#  'two',
#  'typically',
#  'underlying',
#  'understanding',
#  'unit',
#  'unity',
#  'univariate',
#  'university',
#  'unseen',
#  'until',
#  'up',
#  'upsampled',
#  'upsampling',
#  'us',
#  'usa',
#  'usd',
#  'use',
#  'used',
#  'useful',
#  'uses',
#  'using',
#  'validation',
#  'value',
#  'values',
#  'variable',
#  'variables',
#  'variance',
#  'variances',
#  'variant',
#  'varies',
#  'vector',
#  'vectors',
#  'virginica',
#  'visualisation',
#  'want',
#  'wants',
#  'was',
#  'way',
#  'ways',
#  'we',
#  'week',
#  'weekly',
#  'weight',
#  'weighted',
#  'weighting',
#  'weights',
#  'were',
#  'what',
#  'when',
#  'where',
#  'whether',
#  'which',
#  'while',
#  'white',
#  'why',
#  'width',
#  'will',
#  'window',
#  'wish',
#  'with',
#  'within',
#  'without',
#  'words',
#  'work',
#  'working',
#  'works',
#  'world',
#  'would',
#  'wouldn',
#  'write',
#  'written',
#  'wrong',
#  'y',
#  'you',
#  'your',
#  'z',
#  'zero',
#  'zeros'}

# %%
Afrikans
# Out:
# {'<cld>',
#  '<com>',
#  '<eos>',
#  '<ltx>',
#  '<num>',
#  '<opn>',
#  '<prc>',
#  '<sos>',
#  'a',
#  'aan',
#  'aanbeveel',
#  'aandui',
#  'aangedui',
#  'aangel',
#  'aangeteken',
#  'aangetoon',
#  'aanleer',
#  'aanname',
#  'aannames',
#  'aanneem',
#  'aantal',
#  'aanvaar',
#  'aanvaarding',
#  'aanvanklike',
#  'adc',
#  'add',
#  'addisionele',
#  'ado',
#  'af',
#  'afgemonster',
#  'afgeprojekteer',
#  'afgerig',
#  'afleiding',
#  'afloop',
#  'afmonstering',
#  'afnyfrekwensie',
#  'afrig',
#  'afrigakkuraatheid',
#  'afrigdatastel',
#  'afrigfout',
#  'afrigpunte',
#  'afrigverlies',
#  'afsetterm',
#  'afsnyfrekwensie',
#  'afstand',
#  'akkuraathede',
#  'akkuraatheid',
#  'al',
#  'algebra',
#  'algemeen',
#  'algoritme',
#  'aliasing',
#  'all',
#  'alle',
#  'alternatiewe',
#  'amerikaanse',
#  'amplitude',
#  'amplitudes',
#  'amplitudeweergawe',
#  'analitika',
#  'analoog',
#  'and',
#  'ander',
#  'anders',
#  'annotasies',
#  'annoteer',
#  'anti',
#  'antwoord',
#  'antwoorde',
#  'apart',
#  'artist',
#  'as',
#  'asse',
#  'assosiatief',
#  'b',
#  'baie',
#  'bandbeperk',
#  'banddeurlaatfilter',
#  'bandwydte',
#  'basdrom',
#  'basisfunksieontwerpmatriks',
#  'basisfunksies',
#  'basismodel',
#  'bayes',
#  'beantwoord',
#  'bedryf',
#  'beeld',
#  'beeldkompressie',
#  'beginsalaris',
#  'behulp',
#  'beide',
#  'bekend',
#  'bekendgestel',
#  'belangstel',
#  'bemarkingsbegroting',
#  'benadering',
#  'benaderings',
#  'benodig',
#  'bepaal',
#  'beplan',
#  'beraam',
#  'beraming',
#  'beramings',
#  'bereik',
#  'bereken',
#  'berekening',
#  'berekeninge',
#  'berekeningspoed',
#  'beroep',
#  'besef',
#  'beskadig',
#  'beskou',
#  'beskryf',
#  'beslissingsboom',
#  'beslissingsgrens',
#  'beslissingsgrense',
#  'besluit',
#  'bestaan',
#  'bestaande',
#  'beteken',
#  'beurt',
#  'bevat',
#  'bewerkings',
#  'bewys',
#  'biblioteek',
#  'biline',
#  'bin',
#  'binne',
#  'bisse',
#  'blaarnodusse',
#  'bladsy',
#  'blokdiagram',
#  'bloklengte',
#  'blomme',
#  'bly',
#  'bo',
#  'bome',
#  'bondel',
#  'bondeling',
#  'bondelingsalgoritme',
#  'bondelingskonfigurasie',
#  'bondelingstoewysing',
#  'bondels',
#  'boom',
#  'boomkweekalgoritme',
#  'boosting',
#  'bou',
#  'bpf',
#  'breuk',
#  'britse',
#  'bure',
#  'butterworth',
#  'bv',
#  'by',
#  'byvoorbeeld',
#  'c',
#  'covid',
#  'd',
#  'daar',
#  'daarna',
#  'daarom',
#  'daaruit',
#  'daarvan',
#  'dac',
#  'dan',
#  'dat',
#  'data',
#  'datapunte',
#  'datasetel',
#  'datastel',
#  'db',
#  'deeglik',
#  'deel',
#  'definisie',
#  'definisies',
#  'derde',
#  'desimasie',
#  'deur',
#  'deurlaat',
#  'deurlaatband',
#  'dft',
#  'diagonaalkovariansiese',
#  'die',
#  'diepte',
#  'dieselfde',
#  'digitale',
#  'digthede',
#  'digtheid',
#  'dimensie',
#  'dimensies',
#  'dink',
#  'direk',
#  'direkte',
#  'diskrete',
#  'dit',
#  'doel',
#  'doen',
#  'dokter',
#  'dollars',
#  'domein',
#  'dosent',
#  'downsample',
#  'downsampled',
#  'drie',
#  'dromme',
#  'dromslae',
#  'dromstel',
#  'drywing',
#  'drywingsdigtheidspektrum',
#  'drywingssein',
#  'drywingsseine',
#  'dsp',
#  'dtft',
#  'dtmf',
#  'dubbeltoonmultifrekwensie',
#  'dui',
#  'duidelik',
#  'duisend',
#  'duitse',
#  'dus',
#  'e',
#  'een',
#  'eendimensionele',
#  'eenhede',
#  'eenheid',
#  'eenheidssirkel',
#  'eenheidsvariansie',
#  'eenvoudige',
#  'eerder',
#  'eers',
#  'eerste',
#  'effek',
#  'effekte',
#  'effektief',
#  'effektiewe',
#  'effisi',
#  'egter',
#  'eie',
#  'eienskap',
#  'eindige',
#  'einskap',
#  'eintlik',
#  'ekwivalent',
#  'ele',
#  'elk',
#  'elke',
#  'elkeen',
#  'en',
#  'energie',
#  'enige',
#  'enkel',
#  'enkele',
#  'enkelveranderlike',
#  'ent',
#  'ente',
#  'er',
#  'ere',
#  'es',
#  'euklidiese',
#  'euro',
#  'evalueer',
#  'ewe',
#  'faktor',
#  'faktore',
#  'faseweergawes',
#  'fft',
#  'ffts',
#  'figure',
#  'figuur',
#  'filter',
#  'filters',
#  'finale',
#  'fir',
#  'form',
#  'formuleblad',
#  'formules',
#  'fourier',
#  'fout',
#  'fouttiewelik',
#  'frekwensie',
#  'frekwensieresolusie',
#  'frekwensies',
#  'frekwensieweergawe',
#  'freqz',
#  'fundamentele',
#  'funksie',
#  'gaan',
#  'gaussiese',
#  'ge',
#  'geaffekteer',
#  'geanaliseer',
#  'geannoteer',
#  'gebaseer',
#  'gebied',
#  'gebiede',
#  'gebruik',
#  'gedefinieer',
#  'gediskretiseer',
#  'gedrag',
#  'gee',
#  'gefilter',
#  'gegee',
#  'gekies',
#  'geklassifiseer',
#  'geklassifiseerder',
#  'geleer',
#  'gemaak',
#  'gemiddeld',
#  'gemiddelde',
#  'gemodelleer',
#  'gemonster',
#  'gemonsterde',
#  'genereer',
#  'genoeg',
#  'geparameteriseerd',
#  'geparameteriseerde',
#  'gepaste',
#  'geplaas',
#  'gesien',
#  'geskryf',
#  'geslag',
#  'geslote',
#  'gespasie',
#  'gestel',
#  'gestoorde',
#  'gestuur',
#  'getoon',
#  'geval',
#  'gevalle',
#  'gevoeg',
#  'gevolg',
#  'gevolglike',
#  'gevorderde',
#  'geweegde',
#  'gewigsvektor',
#  'gewigte',
#  'gewoonlik',
#  'gierige',
#  'goeie',
#  'graag',
#  'gradi',
#  'greep',
#  'groep',
#  'grond',
#  'gulsige',
#  'h',
#  'haar',
#  'hamming',
#  'hand',
#  'hanteer',
#  'hardloop',
#  'hele',
#  'herbesoek',
#  'herhaal',
#  'herroeptelling',
#  'het',
#  'hier',
#  'hierbo',
#  'hierdie',
#  'ho',
#  'hoe',
#  'hoef',
#  'hoekom',
#  'hoes',
#  'hoeveel',
#  'hoof',
#  'hoofkomponentanalise',
#  'hooflob',
#  'hoog',
#  'hoogdeurlaatfilter',
#  'hoë',
#  'huidiglik',
#  'hul',
#  'hulle',
#  'hy',
#  'hz',
#  'hê',
#  'i',
#  'ideaal',
#  'ideale',
#  'identiteite',
#  'idft',
#  'iede',
#  'iedes',
#  'iemand',
#  'ies',
#  'iets',
#  'iewe',
#  'ii',
#  'ik',
#  'imagin',
#  'implementeer',
#  'impulsweergawe',
#  'in',
#  'indeks',
#  'indekse',
#  'indien',
#  'individuele',
#  'inferensie',
#  'ingenieur',
#  'initialisering',
#  'initialiseringsbenadering',
#  'inneem',
#  'integer',
#  'interpreteer',
#  'interval',
#  'intree',
#  'intreekenmerke',
#  'intrees',
#  'intreesein',
#  'invariante',
#  'inverse',
#  'invoer',
#  'invoerkenmerke',
#  'iris',
#  'is',
#  'issoleer',
#  'it',
#  'item',
#  'items',
#  'iterasie',
#  'jou',
#  'jy',
#  'kan',
#  'keepfilter',
#  'keer',
#  'kenmerk',
#  'kenmerke',
#  'kenmerkvektor',
#  'kenmerkvektore',
#  'kepe',
#  'khz',
#  'klank',
#  'klankgreep',
#  'klankstelsel',
#  'klankvoorbeelde',
#  'klas',
#  'klasse',
#  'klassifikasie',
#  'klassifiseer',
#  'klassifiseerder',
#  'klassifiseerders',
#  'klasspesifieke',
#  'klasvoorwaardelike',
#  'kleinste',
#  'kleinstekwadraat',
#  'kleinstekwadraatpassing',
#  'kleurbeeld',
#  'ko',
#  'kode',
#  'kom',
#  'kompetisieprys',
#  'komponente',
#  'konfigurasie',
#  'konsep',
#  'konstante',
#  'kontinue',
#  'konvergeer',
#  'konvergensie',
#  'konvolusie',
#  'korrek',
#  'korrekte',
#  'kort',
#  'kortliks',
#  'kostefunksie',
#  'kousaal',
#  'kousale',
#  'kruisies',
#  'kruiskorrelasie',
#  'kry',
#  'kunstenaar',
#  'kurve',
#  'kurwe',
#  'kwadratiese',
#  'kwantisering',
#  'kwantiseringsvlakke',
#  'kyk',
#  'l',
#  'laagdeurlaatfilter',
#  'laar',
#  'laastens',
#  'laat',
#  'lae',
#  'le',
#  'lecturer',
#  'lei',
#  'lengte',
#  'let',
#  'lewer',
#  'liedjie',
#  'line',
#  'log',
#  'logistiese',
#  'loots',
#  'lpf',
#  'lti',
#  'lukraak',
#  'lukrake',
#  'lyk',
#  'lyn',
#  'lyne',
#  'lys',
#  'lê',
#  'm',
#  'maak',
#  'maar',
#  'maatskappy',
#  'maatskappye',
#  'maatstaaf',
#  'maatstaf',
#  'mag',
#  'maksimale',
#  'maksimum',
#  'maksimumwaarskynlikheidsberaming',
#  'manier',
#  'maniere',
#  'manlik',
#  'mans',
#  'mark',
#  'masjienleer',
#  'matriek',
#  'meer',
#  'meerveranderlike',
#  'meeste',
#  'merk',
#  'met',
#  'metode',
#  'metodes',
#  'middelpunte',
#  'minder',
#  'minimaliseer',
#  'minimeer',
#  'minimum',
#  'minstens',
#  'miskluk',
#  'mislukking',
#  'model',
#  'modelgewigte',
#  'modelle',
#  'modelleer',
#  'moet',
#  'monster',
#  'monsterfrekwensie',
#  'monsterperiode',
#  'monsters',
#  'monstertempo',
#  'moontlik',
#  'moontlike',
#  'motiveer',
#  'ms',
#  'multidimensionele',
#  'musiek',
#  'n',
#  'na',
#  'naaste',
#  'naby',
#  'nadat',
#  'navorsingsgroep',
#  'neelsie',
#  'neem',
#  'negatief',
#  'negatiewe',
#  'net',
#  'nie',
#  'nll',
#  'nodig',
#  'nog',
#  'normalisering',
#  'nou',
#  'nte',
#  'numeriese',
#  'nuttig',
#  'nuttige',
#  'nuwe',
#  'nyquist',
#  'of',
#  'ola',
#  'om',
#  'omgeskakel',
#  'omsetter',
#  'omsetters',
#  'omskakel',
#  'onafhanklik',
#  'onder',
#  'onderliggende',
#  'onderskeidelik',
#  'onderstaande',
#  'oneindige',
#  'onewe',
#  'onmiddelike',
#  'ons',
#  'ontwerp',
#  'ontwerpsmatriks',
#  'ontwikkel',
#  'onwaar',
#  'onwerp',
#  'ook',
#  'oor',
#  'oordragsfunksie',
#  'ooreen',
#  'ooreenstem',
#  'ooreenstemmende',
#  'oorsprong',
#  'oorspronklike',
#  'oortollige',
#  'oorvleueling',
#  'oorweeg',
#  'op',
#  'opgemonster',
#  'opmonstering',
#  'optimaal',
#  'optimale',
#  'optimaliseer',
#  'orde',
#  'order',
#  'outokorrelasie',
#  'outomaties',
#  'overlap',
#  'pad',
#  'parameters',
#  'parameterstellings',
#  'parametervektor',
#  'pare',
#  'pas',
#  'pass',
#  'passing',
#  'pca',
#  'per',
#  'periode',
#  'periodes',
#  'periodiese',
#  'perongeluk',
#  'persoon',
#  'plaas',
#  'plaasgevind',
#  'plot',
#  'pole',
#  'polinome',
#  'positief',
#  'positiewe',
#  'presies',
#  'presisie',
#  'problematies',
#  'probleme',
#  'produk',
#  'produkte',
#  'produseer',
#  'projeksie',
#  'proses',
#  'prototipe',
#  'prys',
#  'punt',
#  'punte',
#  'python',
#  'r',
#  'raamlengte',
#  'raamsprong',
#  'raamtempo',
#  'rad',
#  'radiale',
#  'radialebasisfunksies',
#  'radiks',
#  'radix',
#  'rbf',
#  'rbfs',
#  'rde',
#  're',
#  'regressie',
#  'regressiemodel',
#  'regressieprobleem',
#  'regressievoorspellingsfunksie',
#  'regtig',
#  'regulariseringsparameter',
#  'resolusie',
#  'resultaat',
#  'resulterende',
#  'rig',
#  'roc',
#  'rondom',
#  'rou',
#  'rowwe',
#  'ruimte',
#  'ruis',
#  's',
#  'sal',
#  'salaris',
#  'scipy',
#  'se',
#  'sein',
#  'seine',
#  'seingenerator',
#  'sekonde',
#  'sekondes',
#  'selfs',
#  'sentro',
#  'ses',
#  'signal',
#  'siklusse',
#  'sinusgolf',
#  'sinvolle',
#  'sirkul',
#  'skalaarkenmerk',
#  'skeiding',
#  'skets',
#  'skikking',
#  'skoenlapper',
#  'skryf',
#  'sleg',
#  'slegs',
#  'sluit',
#  'sne',
#  'so',
#  'sodat',
#  'softmax',
#  'som',
#  'sommige',
#  'soms',
#  'somtyds',
#  'sonder',
#  'soortgelyke',
#  'soos',
#  'sotfmax',
#  'sou',
#  'spar',
#  'speel',
#  'spektra',
#  'spektrale',
#  'spektrogram',
#  'spektrum',
#  'spektum',
#  'spesieke',
#  'spesifiek',
#  'spesifieke',
#  'spesifiseer',
#  'spoed',
#  'stabiel',
#  'standardiseer',
#  'stap',
#  'stappe',
#  'station',
#  'statistiese',
#  'steeds',
#  'stel',
#  'stelsel',
#  'stelsels',
#  'stem',
#  'stft',
#  'stompies',
#  'stoor',
#  'student',
#  'studies',
#  'subreekse',
#  'sukses',
#  'sy',
#  'syfer',
#  'syfersein',
#  't',
#  'tabel',
#  'takke',
#  'te',
#  'teen',
#  'tegniek',
#  'teiken',
#  'teikenuittree',
#  'teken',
#  'tensy',
#  'terme',
#  'terug',
#  'terugdaal',
#  'terwyl',
#  'textbf',
#  'textit',
#  'texttt',
#  'the',
#  'tien',
#  'to',
#  'toe',
#  'toegewys',
#  'toekomstige',
#  'toets',
#  'toetse',
#  'toetspunt',
#  'toevoegingsmodel',
#  'toewysing',
#  'toon',
#  'top',
#  'tot',
#  'totdat',
#  'transform',
#  'transformasie',
#  'transformasies',
#  'trek',
#  'tussen',
#  'twee',
#  'tweede',
#  'tweedimensionele',
#  'tyd',
#  'tydinvariant',
#  'tydinvariante',
#  'tydvariant',
#  'u',
#  'uit',
#  'uitdrukking',
#  'uiteindelik',
#  'uitgevoer',
#  'uitree',
#  'uittree',
#  'uittreeklasse',
#  'uittrees',
#  'uittreeveranderlike',
#  'uitvoerende',
#  'universiteit',
#  'upsample',
#  'usd',
#  'v',
#  'vaar',
#  'val',
#  'validasie',
#  'validasiedata',
#  'validasiestel',
#  'van',
#  'vanaf',
#  'vannaf',
#  'variansie',
#  'variant',
#  'varieer',
#  'vaste',
#  'vector',
#  'veelvuldige',
#  'vektor',
#  'venster',
#  'verander',
#  'verandering',
#  'veranderings',
#  'veranderlikes',
#  'verbeter',
#  'verdien',
#  'verduidelik',
#  'vereistes',
#  'vergelyk',
#  'vergelyking',
#  'vergelykings',
#  'verhouding',
#  'verkope',
#  'verkry',
#  'verlangde',
#  'verlies',
#  'verlieswaardes',
#  'vermenigvuldiging',
#  'vermenigvuldigings',
#  'veronderstel',
#  'veroorsaak',
#  'versamel',
#  'verseker',
#  'verskaf',
#  'verskeie',
#  'verskil',
#  'verskillende',
#  'verskilvergelyking',
#  'verspreiding',
#  'verstaan',
#  'verste',
#  'verteenwoordig',
#  'verwantskap',
#  'verwerk',
#  'verwerker',
#  'verwerkingstelsel',
#  'verwys',
#  'vind',
#  'vinniger',
#  'vir',
#  'virginica',
#  'visualisering',
#  'vlak',
#  'voeg',
#  'voer',
#  'vol',
#  'voldoen',
#  'volg',
#  'volgende',
#  'volgens',
#  'volle',
#  'volledige',
#  'voltooi',
#  'voor',
#  'voorbeeld',
#  'voordat',
#  'voorgekom',
#  'voorheen',
#  'voorkom',
#  'voorspel',
#  'voorspelling',
#  'voorspellings',
#  'voorspellingsfunksie',
#  'voorstel',
#  'voorstelling',
#  'voorverwerkingsmetode',
#  'vorm',
#  'vraag',
#  'vrae',
#  'vriend',
#  'vroeëre',
#  'vrouens',
#  'vroulik',
#  'vsa',
#  'vyf',
#  'w',
#  'waar',
#  'waarde',
#  'waardes',
#  'waarmee',
#  'waarneming',
#  'waarnemings',
#  'waarom',
#  'waarskynlikheid',
#  'waarskynlikheidsberaming',
#  'waarskynlikheidsberamings',
#  'waarskynlikheidskostefunksie',
#  'waarvan',
#  'waarvoor',
#  'wanneer',
#  'warm',
#  'was',
#  'wat',
#  'watter',
#  'week',
#  'weeklikse',
#  'weer',
#  'wees',
#  'weidteparameter',
#  'wek',
#  'wel',
#  'wenk',
#  'wenslik',
#  'werk',
#  'werknemers',
#  'wil',
#  'will',
#  'willekeurige',
#  'winkel',
#  'wins',
#  'wiskundige',
#  'wisselkoers',
#  'wisselpunt',
#  'wit',
#  'woorde',
#  'word',
#  'wys',
#  'wyse',
#  'wêreldaandelemarkte',
#  'z',
#  'zero',
#  'zeros'}
